# %% [markdown]
# # ANALYSIS OF COVID 19
#
#
# ## INTRODUCTION
#
# The covid 19 pandemic also known as the coronavirus is a novel virus caused by severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2).This pandemic, began in a Chinese city called Wuhan on december 2019. The virus was officially declared a Public Health Emergency of International Concern on 30 January 2020 and a pandemic on 11 March 2020. By 26 February 2022, the pandemic had caused more than 433 million cases and 5.93 million deaths,thereby being one of the deadliest pandemics ever recorded.The pandemic brought the entire world to a standstill,with nations making efforts to contain the spread of this deadly virus.As a data analyst mypurpose is to come up us to come up with a scheme that has the best control measures.For more infomation [click here](https://en.wikipedia.org/wiki/COVID-19_pandemic#Strategies)
# ![corona%20image.jpg](attachment:corona%20image.jpg)
#
#
# ### AIM
# The main objective of this analysis is to come up with measures that best control corona virus.
#       For this to be a success we have to import python libraries such as; `pandas`, `numpy` and `matplotlib`
#
# ## 1.1 Importing necessary libraries

# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt


## 1.2 Exploring data
covid_19=pd.read_csv("Downloads/covid_data.xls")
cv_19=covid_19

# %%
# Displaying a few rows
covid_19.head(21)
covid_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Countries         221 non-null    object
#  1   Total_cases       221 non-null    int64
#  2   New cases         221 non-null    float64
#  3   Total_deaths      221 non-null    int64
#  4   New_death         221 non-null    float64
#  5   Total_recovered   221 non-null    int64
#  6   New_recovered     221 non-null    float64
#  7   Active_cases      221 non-null    int64
#  8   Serious/Critical  221 non-null    int64
#  9   Total_cases/1M    221 non-null    float64
#  10  Total_deaths/1M   221 non-null    float64
#  11  Total_tests       221 non-null    int64
#  12  Test/1M           221 non-null    int64
#  13  Popultion         221 non-null    int64
#  14  Continent         221 non-null    object
# dtypes: float64(5), int64(8), object(2)
# memory usage: 26.0+ KB

# %%
def explore_data(dataset, rows_column=False):
    display(dataset.head())
    
    print("\n")
    
    if rows_column:
        print("Number of rows are :"+ str(dataset.shape[0]))
        print("Number of columns are :"+str(dataset.shape[1]))
        
        print("\n")
        
        print(dataset.columns)

# %%
explore_data(covid_19,True)
# Out:
#   Countries  Total_cases  New cases  Total_deaths  New_death  Total_recovered  \
# 0       USA     80697924    41899.0        977402     1451.0         53730805
# 1     India     42938599     7554.0        514246      192.0         42338673
# 2    Brazil     28811165    23545.0        649717      274.0         26506005
# 3    France     22782609    79794.0        138576      209.0         21080886
# 4        UK     18985568    24158.0        161630       15.0         17537214
#
#    New_recovered  Active_cases  Serious/Critical  Total_cases/1M  \
# 0       230543.0      25989717              7522        241447.0
# 1        14123.0         85680              8944         30615.0
# 2       169632.0       1655443              8318        133963.0
# 3       179382.0       1563147              2484        347755.0
# 4        87564.0       1286724               289        277250.0
#
#    Total_deaths/1M  Total_tests  Test/1M   Popultion      Continent
# ...

# %%
covid_19['Total_cases']
# Out:
# 0      80697924
# 1      42938599
# 2      28811165
# 3      22782609
# 4      18985568
#          ...
# 216          53
# 217          33
# 218          29
# 219          18
# 220          10
# Name: Total_cases, Length: 221, dtype: int64

# %% [markdown]
# # 2.0 ANALYSIS OF DATA
#
# In this analysis we will sort out our data from the country with the most covid-19 cases to the least. We will further our analysis by finding the country with the most deaths. In our study we will also find out the countries that optimise and maximize on controlling the spread of the pandemic.
#
# ### 2.0.1 Countries with most covid 19 cases
# Here we will rank the countries from the country with the most covid-19 cases to the country with the least. After which
# we will deduce reasons why the respective countries amass such masses.

# %%
# top ten most affected countries
most_covid=covid_19.sort_values("Total_cases",ascending=False)
most_covid.head(10)
# Out:
#   Countries  Total_cases  New cases  Total_deaths  New_death  Total_recovered  \
# 0       USA     80697924    41899.0        977402     1451.0         53730805
# 1     India     42938599     7554.0        514246      192.0         42338673
# 2    Brazil     28811165    23545.0        649717      274.0         26506005
# 3    France     22782609    79794.0        138576      209.0         21080886
# 4        UK     18985568    24158.0        161630       15.0         17537214
# 5    Russia     16495369    97333.0        352446      786.0         13748465
# 6   Germany     14974713   150565.0        123721      275.0         11239600
# 7    Turkey     14149341    59885.0         94648      203.0         13437729
# 8     Italy     12829972    46631.0        155000      233.0         11601742
# 9     Spain     11036085    14641.0         99883      119.0          9679247
#
#    New_recovered  Active_cases  Serious/Critical  Total_cases/1M  \
# ...

# %% [markdown]
# As shown above The United States of America(USA) has the largest number of cases. The reasons to why USA experienced so many cases is explained below:
#    The first and the most crucial reason why the USA suffered so much devastation is due to the slow responce. The **US** government was slow to respond to the issue this led to further spread of the virus.The preparation of health care system was really slow, the **US** government was also in stopping other travel and was also lax in testing for covid-19. Furthermore, the citizens were ignorant of the set guidelines to control the spread of the virus,for example undercutting wearing of the facial covering. some states in the USA lacked adequate testing infrastructure to fully test their citizens.

# %% [markdown]
# ## 2.1 Coronavirus Cases in different Continents
# In this subsect, we will analyse coronavirus cases of different countries in different continents.

# %%
cv_19= covid_19

cv_19["Continent"].unique()
# Out:
# array(['North America', 'Asia', 'South America', 'Europe', 'Africa',
#        'Australia/Oceania'], dtype=object)

# %% [markdown]
# ### 2.1.1 Coronavirus cases in Africa

# %%
africa_cases= cv_19[cv_19['Continent']=='Africa']
#  top ten most affected countries
top_countries=africa_cases.sort_values('Total_cases',ascending=False).head(10)
top_countries[['Countries','Total_cases']]
# Out:
#        Countries  Total_cases
# 19  South Africa      3675691
# 50       Morocco      1161131
# 55       Tunisia       998230
# 82         Libya       495115
# 83         Egypt       485093
# 84      Ethiopia       468770
# 92         Kenya       322978
# 93        Zambia       312970
# 94       Réunion       302162
# 97       Algeria       265010

# %%
# visualize
plt.bar(top_countries['Countries'],top_countries['Total_cases'],color="red")
plt.xticks(rotation=90)
plt.title("Top ten affected countries(africa)")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %%
plt.pie(top_countries['Total_cases'],labels=top_countries['Countries'])
plt.show()

# %% [markdown]
# ### Reasons why South Africa leads in corona virus cases
#
# (a) Slow response from the government, the state of South Africa was lax in excecution of the required protocol. The delay in response led to further spread of the virus.
# (b) Population density- The population density in South Africa is 49 per Km2 (127 people per mi2),to control the spread of a virus in a country like South Africa is difficult since the virus is easily spread through the population
# (c)Fragile health systems- Africa is generally considered to have fragile health systems that may hamper with control of the spread of the virus.
# (d) Delays in use of the available vaccines. Most of the citizens in South Africa lack confidence in the available vaccines thereby refusing to be vaccinated this led to further spread of the virus.For more info[click here](https://sacoronavirus.co.za/)

# %%
africa_cases= cv_19[cv_19['Continent']=='Africa']
# sum of total cases in africa
africa_cases['Total_cases'].sum()
# Out:
# 11541237

# %% [markdown]
# The total number of cases of coronavirus cases in Africa is 11,541,237.

# %% [markdown]
# ### 2.1.2 Coronavirus cases in North America
# From the data above we found out that **US** was the not only the country with the most coronavirus cases in North America but it was the leading in the entire world. Now let's find out the cases for the rest of North America.

# %%
north_america_cases= cv_19[cv_19['Continent']=='North America']
#  top ten most affected countries
top_countries=north_america_cases.sort_values('Total_cases',ascending=False)
top_countries=top_countries.head(10)
top_countries
# Out:
#               Countries  Total_cases  New cases  Total_deaths  New_death  \
# 0                   USA     80697924    41899.0        977402     1451.0
# 16               Mexico      5508629     2524.0        318149       63.0
# 27               Canada      3296549     3569.0         36638       36.0
# 53                 Cuba      1070258      396.0          8495        1.0
# 64           Costa Rica       809131     2203.0          8047       10.0
# 66            Guatemala       780815     3145.0         17010       33.0
# 67               Panama       755853      355.0          8093       10.0
# 77   Dominican Republic       574912      356.0          4369        1.0
# 87             Honduras       412733     1521.0         10778       58.0
# 112         El Salvador       156364       -1.0          4074        3.0
#
#      Total_recovered  New_recovered  Active_cases  Serious/Critical  \
# 0           53730805       230543.0      25989717              7522
# ...

# %%
#illustrating covid_19 cases in North America using a bar graph
#Top ten countries in North America
plt.bar(top_countries['Countries'],top_countries['Total_cases'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten affected countries(North America)")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %% [markdown]
# As shown above The United States of America(USA) has the largest number of cases. The reasons to why USA experienced so many cases is explained below: The first and the most crucial reason why the USA suffered so much devastation is due to the slow responce. The US government was slow to respond to the issue this led to further spread of the virus.The preparation of health care system was really slow, the US government was also in stopping other travel and was also lax in testing for covid-19. Furthermore, the citizens were ignorant of the set guidelines to control the spread of the virus,for example undercutting wearing of the facial covering. some states in the USA lacked adequate testing infrastructure to fully test their citizens,In Mexico the problems condition is so severe that authorities have to use force for the citizens to adhere to the restrictions put in place. Such ignorance is what plagues the nation of Mexico.

# %%
north_america_cases= cv_19[cv_19['Continent']=='North America']
# sum of total cases in North America 
north_america_cases['Total_cases'].sum()
# Out:
# 94984817

# %% [markdown]
# Total cases in North America is 94,984,817

# %% [markdown]
# ###  2.1.3 Coronavirus cases in South America

# %%
south_america_cases= cv_19[cv_19['Continent']=='South America']
#  top ten most affected countries in South America
top_countries=south_america_cases.sort_values('Total_cases',ascending=False)
top_countries=top_countries.head(10)
top_countries
# Out:
#     Countries  Total_cases  New cases  Total_deaths  New_death  \
# 2      Brazil     28811165    23545.0        649717      274.0
# 10  Argentina      8904176     3520.0        126257      105.0
# 13   Colombia      6065801     1218.0        138854       87.0
# 25       Peru      3518721     1461.0        210744       72.0
# 31      Chile      3076291    13929.0         42381       28.0
# 60    Bolivia       893395       65.0         21438        6.0
# 62    Uruguay       844400     1938.0          6991        6.0
# 63    Ecuador       827760       -1.0         35223       -1.0
# 73   Paraguay       642184      417.0         18392       25.0
# 79  Venezuela       515582      458.0          5639        3.0
#
#     Total_recovered  New_recovered  Active_cases  Serious/Critical  \
# 2          26506005       169632.0       1655443              8318
# 10          8688724         6534.0         89195              1136
# 13          5892530         1967.0         34417               342
# ...

# %%
plt.bar(top_countries['Countries'],top_countries['Total_cases'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten affected countries(South America)")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %% [markdown]
#  Government mismanagement is the core plague in Brazil,the authorities being ignorant of the evidence-based  public health measures has led many to their early grave. The situation in Brazil is drastic this also because of the high population in Brazil where most of the people in are situated in densely populated areas making it more difficult to contain the spread of the virus. The level of poverty in Brazil is also another factor that has led to further spread since the people therein have to go about their daily lives in pursuit of something to feed, this has led to laxity in following the restrictions that curb its spread. The residents in Brazil fail to use facial covering and practice social distancing as advised by medical experts, For information[click](http://www.dw.com/en/)

# %%
south_america_cases= cv_19[cv_19['Continent']=='South America']
# sum of total cases in africa
south_america_cases['Total_cases'].sum()
# Out:
# 54318479

# %% [markdown]
# Total cases in the continent of South America is 54,318,479

# %% [markdown]
# ### 2.1.4 Coronavirus cases in Asia

# %%
Asia_cases= cv_19[cv_19['Continent']=='Asia']
#  top ten most affected countries
top_countries=Asia_cases.sort_values('Total_cases',ascending=False)
top_countries=top_countries.head(10)
top_countries
# Out:
#       Countries  Total_cases  New cases  Total_deaths  New_death  \
# 1         India     42938599     7554.0        514246      192.0
# 7        Turkey     14149341    59885.0         94648      203.0
# 11         Iran      7060741     9312.0        137064      226.0
# 15    Indonesia      5589176    24728.0        148660      325.0
# 17        Japan      5005892    55243.0         23633      187.0
# 20  Philippines      3663059     1067.0         56451       -1.0
# 21       Israel      3641304     6794.0         10218       20.0
# 23      Vietnam      3557629    98762.0         40338       86.0
# 26     Malaysia      3468590    25854.0         32827       78.0
# 29     S. Korea      3273449   138993.0          8170      112.0
#
#     Total_recovered  New_recovered  Active_cases  Serious/Critical  \
# 1          42338673        14123.0         85680              8944
# 7          13437729        71545.0        616964              1128
# ...

# %%
plt.bar(top_countries['Countries'],top_countries['Total_cases'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten affected countries(Asia)")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %%
plt.pie(top_countries['Total_cases'],labels=top_countries['Countries'])
plt.show()

# %%
asia_cases= cv_19[cv_19['Continent']=='Asia']
# sum of total cases in africa
asia_cases['Total_cases'].sum()
# Out:
# 117291566

# %% [markdown]
# Total cases Asia is 117,291,566

# %% [markdown]
# his note discusses the consequences of the COVID-19 crisis on financing for sustainable development in low- and middle-income countries eligible for official development assistance (ODA). Levels and trends in domestic and external financing already fell short of the SDG spending needs prior to the COVID-19 crisis. The current global context, however, risks a significant reduction in the financing available to developing economies. In sum, external private finance inflows to developing economies could drop by USD 700 billion in 2020 compared to 2019 levels, exceeding the immediate impact of the 2008 Global Financial Crisis by 60%. This exacerbates the risk of major development setbacks that would, in turn, increase our vulnerability to future pandemics, climate change and other global public bads. While official development finance is an important countercyclical force in the short-term and tax revenues remain the only long-term viable source of financing for many public services, no single source of development finance can take up this challenge alone. Actors in development finance and beyond need to collaborate closely to “build back better” for a more equitable, sustainable and thus resilient world.

# %% [markdown]
# ### 2.1.5 Countries with most corona cases in Europe

# %%
europe_cases= cv_19[cv_19['Continent']=='Europe']
#  top ten most affected countries in Europe
top_countries=europe_cases.sort_values('Total_cases',ascending=False)
top_countries=top_countries.head(10)
top_countries
# Out:
#       Countries  Total_cases  New cases  Total_deaths  New_death  \
# 3        France     22782609    79794.0        138576      209.0
# 4            UK     18985568    24158.0        161630       15.0
# 5        Russia     16495369    97333.0        352446      786.0
# 6       Germany     14974713   150565.0        123721      275.0
# 8         Italy     12829972    46631.0        155000      233.0
# 9         Spain     11036085    14641.0         99883      119.0
# 12  Netherlands      6398114    36488.0         21570       16.0
# 14       Poland      5680034    12984.0        111586      269.0
# 18      Ukraine      4809624       -1.0        105505       -1.0
# 22      Czechia      3587871    10159.0         38685       18.0
#
#     Total_recovered  New_recovered  Active_cases  Serious/Critical  \
# 3          21080886       179382.0       1563147              2484
# 4          17537214        87564.0       1286724               289
# ...

# %%
plt.bar(top_countries['Countries'],top_countries['Total_cases'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten affected countries(Asia)")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %%
europe_cases= cv_19[cv_19['Continent']=='Europe']
# sum of total cases in Europe
europe_cases['Total_cases'].sum()
# Out:
# 156877781

# %% [markdown]
# Total cases in EUROPE is 156,877,781

# %%
plt.pie(top_countries['Total_cases'],labels=top_countries['Countries'])
plt.show()

# %% [markdown]
# ### 2.1.6 Covid_19 cases in Australia/Oceania

# %%
oceania_cases= cv_19[cv_19['Continent']=='Australia/Oceania']
#  top ten most affected countries in Europe
top_countries=oceania_cases.sort_values('Total_cases',ascending=False)
top_countries=top_countries.head(10)
top_countries
# Out:
#              Countries  Total_cases  New cases  Total_deaths  New_death  \
# 30           Australia      3236095    25017.0          5212       41.0
# 121        New Zealand       118812    17991.0            56       -1.0
# 134   French Polynesia        67651      952.0           641        2.0
# 135               Fiji        63930       -1.0           834       -1.0
# 143      New Caledonia        54856      679.0           300        1.0
# 147   Papua New Guinea        41290       -1.0           638       -1.0
# 199    Solomon Islands         7258      209.0           106        7.0
# 206              Palau         3781       -1.0             6       -1.0
# 208           Kiribati         2940       13.0            11       -1.0
# 211  Wallis and Futuna          454       -1.0             7       -1.0
#
#      Total_recovered  New_recovered  Active_cases  Serious/Critical  \
# 30           3030616        28929.0        200267               131
# ...

# %%
plt.bar(top_countries['Countries'],top_countries['Total_cases'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten affected countries(Asia)")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %%
australia_cases= cv_19[cv_19['Continent']=='Australia/Oceania']
# sum of total cases in Australia
australia_cases['Total_cases'].sum()
# Out:
# 3597526

# %% [markdown]
# total cases in Australia/Oceania is 3.5 million

# %% [markdown]
# #  3.0 COUNTRIES WITH MOST DEATH CASES WORLDWIDE
# In this subsect we will rank nations from the country that suffered the most deaths to the country with the least number.

# %%
cv_19.sort_values('Total_deaths',ascending= False, inplace=True)
most_deaths=cv_19[['Countries', 'Total_deaths',]]
most_deaths
# Out:
#             Countries  Total_deaths
# 0                 USA        977402
# 2              Brazil        649717
# 1               India        514246
# 5              Russia        352446
# 16             Mexico        318149
# ..                ...           ...
# 214  Falkland Islands            -1
# 215             Macao            -1
# 216      Cook Islands            -1
# 217             Samoa            -1
# 218      Vatican City            -1
#
# [221 rows x 2 columns]

# %% [markdown]
# As shown above the **USA** has the most deaths worldwide having 977402 while the Vatican is the country with the least number of deaths having 0 deaths.

# %% [markdown]
# ##  3.1 Analysis of deaths per continent

# %% [markdown]
# Let us make our analysis more convinient and easily accessible by finding the  countries with the leading number of deaths per continent.

# %% [markdown]
# ## 3.1.1 Death cases in Europe

# %%
europe_death_cases=cv_19[cv_19['Continent']=='Europe']
europe_death_cases[['Countries','Total_deaths','New_death']]
# Out:
#                   Countries  Total_deaths  New_death
# 5                    Russia        352446      786.0
# 4                        UK        161630       15.0
# 8                     Italy        155000      233.0
# 3                    France        138576      209.0
# 6                   Germany        123721      275.0
# 14                   Poland        111586      269.0
# 18                  Ukraine        105505       -1.0
# 9                     Spain         99883      119.0
# 34                  Romania         63578      146.0
# 42                  Hungary         44051      102.0
# 22                  Czechia         38685       18.0
# 51                 Bulgaria         35637       56.0
# 24                  Belgium         30179       17.0
# 38                   Greece         25914       54.0
# 12              Netherlands         21570       16.0
# 28                 Portugal         21086       23.0
# 46                 Slovakia         18530       45.0
# ...

# %%
# Top ten cases in Europe
europe_death_cases=cv_19[cv_19['Continent']=='Europe']
europe_death_cases=europe_death_cases[['Countries','Total_deaths','New_death']]
top_countries=europe_death_cases.sort_values('Total_deaths',ascending=False)
top_countries=top_countries.head(10)
top_countries
# Out:
#    Countries  Total_deaths  New_death
# 5     Russia        352446      786.0
# 4         UK        161630       15.0
# 8      Italy        155000      233.0
# 3     France        138576      209.0
# 6    Germany        123721      275.0
# 14    Poland        111586      269.0
# 18   Ukraine        105505       -1.0
# 9      Spain         99883      119.0
# 34   Romania         63578      146.0
# 42   Hungary         44051      102.0

# %%
plt.bar(top_countries['Countries'],top_countries['Total_deaths'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten death cases in Europe")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %%
plt.pie(top_countries['Total_deaths'],labels=top_countries['Countries'])
plt.show()

# %%
europe_cases= cv_19[cv_19['Continent']=='Europe']
# sum of total  death cases in europe
europe_cases['Total_deaths'].sum()
# Out:
# 1711410

# %% [markdown]
# Total death cases in Europe is 1.7 million

# %% [markdown]
# ## 3.1.2 Death cases in North America

# %%
north_america=cv_19[cv_19['Continent']=='North America']
north_america[['Countries','Total_deaths','New_death']]
# Out:
#                   Countries  Total_deaths  New_death
# 0                       USA        977402     1451.0
# 16                   Mexico        318149       63.0
# 27                   Canada         36638       36.0
# 66                Guatemala         17010       33.0
# 87                 Honduras         10778       58.0
# 53                     Cuba          8495        1.0
# 67                   Panama          8093       10.0
# 64               Costa Rica          8047       10.0
# 77       Dominican Republic          4369        1.0
# 112             El Salvador          4074        3.0
# 117     Trinidad and Tobago          3632        4.0
# 118                 Jamaica          2814        1.0
# 122              Martinique           895       19.0
# 119              Guadeloupe           837       -1.0
# 162                   Haiti           820       -1.0
# 158                 Bahamas           771       -1.0
# 140                  Belize           650       -1.0
# ...

# %%
north_america_death_cases=cv_19[cv_19['Continent']=='North America']
north_america_death_cases[['Countries','Total_deaths',]]
top_countries=north_america_death_cases.sort_values('Total_deaths',ascending=False)
top_countries=top_countries[['Countries','Total_deaths','New_death']].head(10)
top_countries
# Out:
#               Countries  Total_deaths  New_death
# 0                   USA        977402     1451.0
# 16               Mexico        318149       63.0
# 27               Canada         36638       36.0
# 66            Guatemala         17010       33.0
# 87             Honduras         10778       58.0
# 53                 Cuba          8495        1.0
# 67               Panama          8093       10.0
# 64           Costa Rica          8047       10.0
# 77   Dominican Republic          4369        1.0
# 112         El Salvador          4074        3.0

# %%
# Top ten countries wiht death

# %%
plt.bar(top_countries['Countries'],top_countries['Total_deaths'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten death cases in North America")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %%
north_america_cases= cv_19[cv_19['Continent']=='North America']
# sum of total cases in North America 
north_america_cases['Total_deaths'].sum()
# Out:
# 1405851

# %% [markdown]
# Total death cases in North America  is 1.4 million

# %% [markdown]
# ## 3.1.3 Death cases in South America

# %%
south_america=cv_19[cv_19['Continent']=='South America']
south_america[['Countries','Total_deaths','New_death']]
# Out:
#             Countries  Total_deaths  New_death
# 2              Brazil        649717      274.0
# 25               Peru        210744       72.0
# 13           Colombia        138854       87.0
# 10          Argentina        126257      105.0
# 31              Chile         42381       28.0
# 63            Ecuador         35223       -1.0
# 60            Bolivia         21438        6.0
# 73           Paraguay         18392       25.0
# 62            Uruguay          6991        6.0
# 79          Venezuela          5639        3.0
# 129          Suriname          1317        1.0
# 137            Guyana          1220       -1.0
# 130     French Guiana           391       -1.0
# 214  Falkland Islands            -1       -1.0

# %%
south_america_death_cases=cv_19[cv_19['Continent']=='South America']
south_america[['Countries','Total_deaths','New_death']]
top_countries=south_america_death_cases.sort_values('Total_deaths',ascending=False)
top_countries=top_countries[['Countries','Total_deaths','New_death']].head(10)
top_countries
# Out:
#     Countries  Total_deaths  New_death
# 2      Brazil        649717      274.0
# 25       Peru        210744       72.0
# 13   Colombia        138854       87.0
# 10  Argentina        126257      105.0
# 31      Chile         42381       28.0
# 63    Ecuador         35223       -1.0
# 60    Bolivia         21438        6.0
# 73   Paraguay         18392       25.0
# 62    Uruguay          6991        6.0
# 79  Venezuela          5639        3.0

# %%
plt.bar(top_countries['Countries'],top_countries['Total_deaths'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten death cases in South America")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %%
# give comments on number of deaths and reasons for such numbers

# %%
south_america_cases= cv_19[cv_19['Continent']=='South America']
# sum of total cases in South America
south_america_cases['Total_deaths'].sum()
# Out:
# 1258563

# %% [markdown]
# Total deaths in South America is 1.26 million

# %% [markdown]
# ## 3.1.4 Death cases Asia

# %%
asia=cv_19[cv_19['Continent']=='Asia']
asia[['Countries','Total_deaths','New_death']]
# Out:
#         Countries  Total_deaths  New_death
# 1           India        514246      192.0
# 15      Indonesia        148660      325.0
# 11           Iran        137064      226.0
# 7          Turkey         94648      203.0
# 20    Philippines         56451       -1.0
# 23        Vietnam         40338       86.0
# 26       Malaysia         32827       78.0
# 45       Pakistan         30196       18.0
# 40     Bangladesh         29045        8.0
# 39           Iraq         24999       10.0
# 17          Japan         23633      187.0
# 32       Thailand         22979       43.0
# 75        Myanmar         19372        4.0
# 72      Sri Lanka         16244       22.0
# 44        Georgia         16199       36.0
# 43         Jordan         13849       14.0
# 48     Kazakhstan         13606       10.0
# 56          Nepal         11938        2.0
# 21         Israel         10218       20.0
# 52        Lebanon         10104       13.0
# 65     Azerbaijan          9438       21.0
# ...

# %%
asia_death_cases=cv_19[cv_19['Continent']=='Asia']
asia[['Countries','Total_deaths','New_death']]
top_countries=asia_death_cases.sort_values('Total_deaths',ascending=False)
top_countries=top_countries[['Countries','Total_deaths','New_death']].head(10)
top_countries
# Out:
#       Countries  Total_deaths  New_death
# 1         India        514246      192.0
# 15    Indonesia        148660      325.0
# 11         Iran        137064      226.0
# 7        Turkey         94648      203.0
# 20  Philippines         56451       -1.0
# 23      Vietnam         40338       86.0
# 26     Malaysia         32827       78.0
# 45     Pakistan         30196       18.0
# 40   Bangladesh         29045        8.0
# 39         Iraq         24999       10.0

# %%
plt.bar(top_countries['Countries'],top_countries['Total_deaths'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten death cases in Asia")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %%
plt.pie(top_countries['Total_deaths'],labels=top_countries['Countries'])
plt.show()

# %%
asia_cases= cv_19[cv_19['Continent']=='Asia']
# sum of total cases in asia
asia_cases['Total_deaths'].sum()
# Out:
# 1350427

# %% [markdown]
# Total deaths in Asia is 1.35 million

# %% [markdown]
# ## 3.1.5 Death cases in Australia/Oceania

# %%
australia=cv_19[cv_19['Continent']=='Australia/Oceania']
australia[['Countries','Total_deaths','New_death']]
# Out:
#              Countries  Total_deaths  New_death
# 30           Australia          5212       41.0
# 135               Fiji           834       -1.0
# 134   French Polynesia           641        2.0
# 147   Papua New Guinea           638       -1.0
# 143      New Caledonia           300        1.0
# 199    Solomon Islands           106        7.0
# 121        New Zealand            56       -1.0
# 208           Kiribati            11       -1.0
# 211  Wallis and Futuna             7       -1.0
# 206              Palau             6       -1.0
# 219            Vanuatu             1       -1.0
# 212              Tonga            -1       -1.0
# 216       Cook Islands            -1       -1.0
# 217              Samoa            -1       -1.0

# %%
plt.bar(australia['Countries'],australia['Total_deaths'],color="purple")
plt.xticks(rotation=90)
plt.title("Top ten death cases in Australia/Oceania")
plt.xlabel('countries')
plt.ylabel('Total covid cases(millions)')
plt.show()

# %%
australia_cases= cv_19[cv_19['Continent']=='Australia/Oceania']
# sum of total  death cases in australia
australia_cases['Total_deaths'].sum()
# Out:
# 7809

# %% [markdown]
# Among all the continents Australia has the least number of deaths with 7,809.
# This is due to the speedy response of the Australian Government,restrictions were  put in place immediately after the declaration of the first coronavirus case. Restrictions on movements and travel were restricted, lockdowns were put in place which greatly reduced the spread of the virus, some of the restrictions put in place were;
# Pubs,schools,hospitality venues, fitness centers,galleries and museums,places of worship and nightclubs only allowed to hold a maximum 0f 150 people with two square meters apart. Cinemas and stdiums could only allow 50% capacity limit and many more restrictions ,for further clarification please [visit](: https://ab.co/2OB7Mk1)

# %% [markdown]
# ## 3.1.6 Death cases in Africa
#
# Here we will find out more about the countries in Africa with the most cases.

# %%
africa=cv_19[cv_19['Continent']=='Africa']
africa[['Countries','Total_deaths','New_death',]]
# Out:
#                  Countries  Total_deaths  New_death
# 19            South Africa         99430       18.0
# 55                 Tunisia         27784       -1.0
# 83                   Egypt         24110       36.0
# 50                 Morocco         15994        6.0
# 84                Ethiopia          7463        1.0
# 97                 Algeria          6840        5.0
# 82                   Libya          6269        8.0
# 92                   Kenya          5639       -1.0
# 101               Zimbabwe          5395       -1.0
# 111                Namibia          4007       -1.0
# 93                  Zambia          3953        1.0
# 138                  Sudan          3909        1.0
# 109                 Uganda          3588       -1.0
# 99                 Nigeria          3142       -1.0
# 98                Botswana          2619       -1.0
# 127                 Malawi          2615       -1.0
# 104             Mozambique          2192       -1.0
# ...

# %%
africa_death_cases=cv_19[cv_19['Continent']=='Africa']
africa[['Countries','Total_deaths','New_death']]
top_countries=africa_death_cases.sort_values('Total_deaths',ascending=False)
top_countries=top_countries[['Countries','Total_deaths','New_death']].head(10)
top_countries
# Out:
#         Countries  Total_deaths  New_death
# 19   South Africa         99430       18.0
# 55        Tunisia         27784       -1.0
# 83          Egypt         24110       36.0
# 50        Morocco         15994        6.0
# 84       Ethiopia          7463        1.0
# 97        Algeria          6840        5.0
# 82          Libya          6269        8.0
# 92          Kenya          5639       -1.0
# 101      Zimbabwe          5395       -1.0
# 111       Namibia          4007       -1.0

# %%
plt.bar(top_countries['Countries'],top_countries['Total_deaths'],color="pink")
plt.xticks(rotation=90)
plt.title("Top ten death cases in Africa")
plt.xlabel('countries')
plt.ylabel('Total covid cases(thousands)')
plt.show()

# %%
africa_cases= cv_19[cv_19['Continent']=='Africa']
# sum of total  death cases in africa
africa_cases['Total_deaths'].sum()
# Out:
# 249635

# %% [markdown]
# Total deaths in Africa Due to coronavirus is 249635

# %% [markdown]
# # 4.0 Controlling the spread of the coronavirus
#
# Here, we will discuss on which nations worlwide had taken the most effective measures to control the spread of the virus.From our analysis we expect that the country that had the most effective measures to control the spread of the virus is the country with the least considerable active cases as compared to their total cases.

# %%
most_covid_control=covid_19.sort_values("New cases",ascending=False)
most_covid_control[['Countries','Total_cases','New cases']].head(-1)

# %% [markdown]
# In our analysis it is well indicated  that Germany had the most rising cases in the world having 150565 people test positive for the coronavirus cases.
#
# ### 4.0.1 Reasons why Germany reigns in new cases of coronavirus despite vaccination
#
# Despite 67% the German population being vaccinated the spread of the virus is still at an all time high. This is because this number is still under 75% of Germany's entire population therefore this number is still not good enough to keep the virus at bay. Secondly, the growing numbers among the unvaccinated could also take a heavy toll on the vaccinated. The more the number grows by day the more affected the population gets,the most affected people are the elderly especially those well above sixty years. Moreover, lately there has been fewer contact restrictions. Germany has been lax in restricting contact and mobility among its citizens.Nowadays Germany faces less rigid restrictions.Another reason for this insane increase in numbers is that the delta variant is more infectious. The delta variant is a  more infectious and more contagious mutation of the coronavirus. The seasonal effect is also another reason for the spread of the virus, since Germany are currently in the winter season it becomes way easier for the spread of the virus, since the delta variant thrives under cold conditions.Lastly,Germany is not the only country facing this surge of cases but also its neighbouring European nations such as Russia and France have also recorded pretty high new cases.For more information considering Germany's coronavirus progress[click here](https://www.dw.com/en/5-reasons-germanys-covid-19-infections-are-soaring/a-59793087)

# %% [markdown]
# ## 4.1.1 Countries least affected by the virus
#
# From the above table it is evident that some countries have been barely affected by the virus, countries like Bermuda, CAR, San Marino, Guadelupe and St. Vincent Grenadines have merely reported any new cases. A country like St. Vincent Grenadines has done wonderfully well keeping the spread of the spread of the virus at bay having reported only 106 deaths from the onset of the pandemic and having recovered patients of 6,627 from the 6,742 confirmed victims. This country has put in place strict contact restriction upon its citizens, stalls cannot offer services unless one is vaccinated, use of facial covering when out in the public is a must. In St. Vincent Grenadines they have put very strict travel policies where one must have had the complete coronavirus vaccination. This measures have proved to be effective considering how the country has been able to control the spread of the pandemic. For more information [click](https://wwwnc.cdc.gov/travel/notices/covid-4/coronavirus-saint-vincent-and-the-grenadines)

# %% [markdown]
# ### Leading countries in coronavirus confirmed cases
# Let us now analyse how the top ten most affected countries are fairing when it comes to new cases.Considering that the**USA** was the most affected it is more crucial to find out how many new cases they had.

# %%
# Top ten affected countries

most_covid=covid_19.sort_values("Total_cases",ascending=False)
most_covid[['Countries','Total_cases','New cases']].head(10)

# %% [markdown]
# Overally, India has well controlled the number of cases among its population having only 7554 out of the 42938599 total cases, The** USA** has also done considerably well considering it has cut the rising cases by nearly 22% each week. This considerable change in case rise in the**USA** was brought about since the country became more aware of the condition and began to seriously control it by;
# (a) Vaccination
# United States has administered at least 553,778,476 doses of COVID vaccines so far. Assuming every person needs 2 doses, that’s enough to have vaccinated about 84.4% of the country’s population.  This led to a considerable decrease in the coronavirus cases.
# (b)Lockdown
# The**USA**has been very keen on shutting down places like schools, workplaces and international borders in order to contain the spread of the virus.
#       India has also made a milestone in decreasing the number of cases reported daily this is mostly made possible through vaccination. India has administered at least 1,778,253,673 doses of COVID vaccines so far. Assuming every person needs 2 doses, that’s enough to have vaccinated about 65.1% of the country’s population. For more information [click](https://graphics.reuters.com/)

# %% [markdown]
# ## Countries with least covid-19 cases

# %%
least_covid=covid_19.sort_values("Total_cases",ascending=True)
least_covid[['Countries','Total_cases','New cases']].head(10)

# %% [markdown]
# Western Sahara is the country with the least number of cases worldwide. This is because;
# (a) Estimations and data collected by the Elsevier Public Health Data Collection deduced that, a 1 °C decrease in average temperature around this quarter of the year (January-March) is associated with about 3.8% increase in the number of active cases of COVID-19.Therefore  countries with relatively higher temperature at this time of the year would tend to have a relatively lower number of cases. Hence the sub saharan countries would have relatively lower cases.
# (b) The Western Sahara has a low population density, which makes the spread of the virus more difficult. With a population of 538000, thereby having only 5 people per square mile Western Sahara is on of the most sparsely populated areas worldwide.This makes the virus less likely to spread.
# (c) Urban population in Western Sahara is low with only 40% of its population living in cities, this inhibits the spread of the novel coronavirus.

# %% [markdown]
# # Summary
#
#   From the analysis above we found out that **Germany** is the country with the **most active cases** worldwide. This makes Germany the country that has least controlled the spread of the virus in the world.
#
#   We have also found out that **Western Sahara** has recorded zero active cases and having the least number of total cases worldwide(10).
#
#   In the analysis it is also safe to say that **Guadeloupe** is the country that **most controlled** the spread of the virus this is because the country initially had a total of 126,642 cases while having close to zero active cases.
#
#   We also have that **USA** has the **most cases worldwide** having 80,697,924 cases.
#
#   **Brazil** has the most cases in South America 28,811,165 cases.
#
#   **India** has the most cases in Asia 42,938,599 cases.
#
#   **South Africa** has the leading cases in Africa 3,675,691 cases
#
#   **Australia** has the leading cases in Australia/Oceania 3,236,095 cases.
#
#   **France** has the leading cases in Europe having 22,782,609 cases.
#
#   #### ** Most deaths**
#
#    Not only is the **USA** leading in deaths in North America but also the entire world having a total of 977,402 deaths.
#
#   **Brazil** leads in death in South America having 649,717
#
#   **India** leads Asia in total number of deaths having 514,246 death cases.
#
#   **Russia** has the most death cases in Europe with 352,446 cases.
#
#   **South Africa** has the most deaths in Africa with 99,430 death cases
#
#   **Australia** has the least leading number of deaths among all the continents with 5212 deaths. Australia recorded the least number of deaths as compared to other continents.
#     **Europe** is the continent with the most deaths registering 1.7 million deaths then followed by **North America** having 1.4 million deaths,**Asia** follows by having 1.3 million deaths while **South America** has 1.2 million death cases,**Africa**holds a 249635 death cases while **AUstralia** has 7809 death cases
#
#   #### Total death cases worldwide
#   The total death cases worldwide is 5,983,695
#
#
#   ### Continent with most coronavirus cases
#
#   Let us rank continents from the most affected to the least affected.
#   The  continent with the most coronavirus cases is;
#   (a) **Europe** with 156,877,781
#   (b)**Asia** with 117,291,566
#   (c)**North America** having 94,984,817
#   (d)**South America** having 54,318,479
#   (e)**Africa** having 11,541,237
#   (f)**Australia/Oceania** having the least covid-19 cases at 3,597,226

# %% [markdown]
# # Recommendation

# %%
australia=cv_19[cv_19['Continent']=='Australia/Oceania']
australia[['Countries','Total_deaths','New_death']]
# Out:
#              Countries  Total_deaths  New_death
# 30           Australia          5212       41.0
# 135               Fiji           834       -1.0
# 134   French Polynesia           641        2.0
# 147   Papua New Guinea           638       -1.0
# 143      New Caledonia           300        1.0
# 199    Solomon Islands           106        7.0
# 121        New Zealand            56       -1.0
# 208           Kiribati            11       -1.0
# 211  Wallis and Futuna             7       -1.0
# 206              Palau             6       -1.0
# 219            Vanuatu             1       -1.0
# 212              Tonga            -1       -1.0
# 216       Cook Islands            -1       -1.0
# 217              Samoa            -1       -1.0

# %% [markdown]
#    Australia as a continent recorded the least number of deaths which is very commendable,this was made possible due to the flawless cooperation between the Australian government and its citizens. The restrictions put in place by the government for example use of facial covering, avoiding by all means crowded places, maimtain social distancing of two meters apart,limit on the capacity at enjoyment joints and religious places, practice good hygiene, wash your hands frequently to reduce the spread of the virus and most of all all citizens should ensure they get vaccinated for the coronavirus.
#    By following the set guidelines and restrictions therein it is without a doubt that we as the entire globe we will reduce the spread of the virus and perhaps even terminate it for good.
